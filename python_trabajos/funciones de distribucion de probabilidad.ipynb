# %% [markdown]
# DISTRIBUCION UNIFORME

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=1
b=100
n=100000
data=np.random.uniform(a,b,n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([10054.,  9975., 10075., 10027.,  9961.,  9911., 10065.,  9942.,
#          9973., 10017.]),
#  array([ 1.00009378, 10.90003696, 20.79998014, 30.69992331, 40.59986649,
#         50.49980967, 60.39975285, 70.29969603, 80.19963921, 90.09958239,
#         99.99952556]),
#  <a list of 10 Patch objects>)

# %%
# distribucion normal 
data= np.random.randn(100)

# %%
x= range(1,101)
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([ 5.,  3., 11., 15., 13., 16., 16.,  7.,  6.,  8.]),
#  array([-2.17992323, -1.77766517, -1.37540711, -0.97314904, -0.57089098,
#         -0.16863291,  0.23362515,  0.63588322,  1.03814128,  1.44039934,
#          1.84265741]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Simulacion de montecarlo

# %%
def pi_montecarlo(n,n_exp):
    pi_avg=0
    pi_value_list=[]
    for i in range(n_exp):
        value= 0
        x=np.random.uniform(0,1,n).tolist()
        y=np.random.uniform(0,1,n).tolist()
        for j in range(n):
            z=np.sqrt(x[j] * x[j] + y[j] * y[j])
            if z <=1:
                value += 1
        float_value=float(value)
        pi_value=float_value*4/n
        pi_value_list.append(pi_value)
        pi_avg += pi_value

    pi=pi_avg/n_exp

    print (pi)
    fig=plt.plot(pi_value_list)

    return(pi,fig)

# %%
pi_montecarlo(10000, 200)
# Out:
# 3.1428160000000007
# (3.1428160000000007, [<matplotlib.lines.Line2D at 0x20e31427d88>])

# %%
n=1000000
data=pd.DataFrame (     
   {
      'A':np.random.randn(n),
      'b':1.5 + 2.5 * np.random.randn(n),
      'c':np.random.uniform(5,32,n)        
   }
)

# %%
data.describe()
# Out:
#                     A               b               c
# count  1000000.000000  1000000.000000  1000000.000000
# mean         0.000478        1.495482       18.489991
# std          0.998624        2.499641        7.793226
# min         -5.189142      -10.355187        5.000031
# 25%         -0.674057       -0.191822       11.754516
# 50%          0.001240        1.496399       18.472182
# 75%          0.673345        3.181306       25.238627
# max          4.796608       14.017202       31.999948

# %%
plt.hist(data["A"])
# Out:
# (array([1.50000e+01, 6.69000e+02, 1.33030e+04, 1.01944e+05, 3.05612e+05,
#         3.67686e+05, 1.75081e+05, 3.31010e+04, 2.51400e+03, 7.50000e+01]),
#  array([-5.18914248, -4.19056741, -3.19199234, -2.19341727, -1.1948422 ,
#         -0.19626712,  0.80230795,  1.80088302,  2.79945809,  3.79803316,
#          4.79660823]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["b"])
# Out:
# (array([8.70000e+01, 2.51400e+03, 3.20610e+04, 1.66112e+05, 3.52875e+05,
#         3.12355e+05, 1.15421e+05, 1.74250e+04, 1.12600e+03, 2.40000e+01]),
#  array([-10.35518738,  -7.91794843,  -5.48070948,  -3.04347053,
#          -0.60623157,   1.83100738,   4.26824633,   6.70548529,
#           9.14272424,  11.57996319,  14.01720215]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["c"])
# Out:
# (array([100177.,  99903.,  99863., 100821., 100257.,  99868.,  99939.,
#          99690.,  99393., 100089.]),
#  array([ 5.00003119,  7.70002284, 10.4000145 , 13.10000615, 15.79999781,
#         18.49998947, 21.19998112, 23.89997278, 26.59996443, 29.29995609,
#         31.99994775]),
#  <a list of 10 Patch objects>)

# %%
data=pd.read_csv("./Documents/Python Scripts/datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %%
Colum_names=data.columns.values.tolist()

# %%
a = len(Colum_names)
a
# Out:
# 21

# %%
new_data= pd.DataFrame(
    { 
       'Column Name': Colum_names,
        'A': np.random.randn(a),
        'B': np.random.uniform(0,1,a)
        
    
    }, index=range(42,42 + a)

)

# %%
new_data
# Out:
#        Column Name         A         B
# 42           State -0.645011  0.885842
# 43  Account Length  0.491430  0.006134
# 44       Area Code  0.815882  0.771712
# 45           Phone -0.340768  0.553958
# 46      Int'l Plan -0.829405  0.157333
# 47      VMail Plan  2.959033  0.172725
# 48   VMail Message  0.838573  0.627748
# 49        Day Mins -1.103191  0.644713
# 50       Day Calls -0.422298  0.477144
# 51      Day Charge  0.677869  0.872707
# 52        Eve Mins  0.892971  0.510928
# 53       Eve Calls -0.597558  0.734185
# 54      Eve Charge  0.598327  0.355333
# 55      Night Mins  1.065482  0.555523
# 56     Night Calls -1.356910  0.732896
# 57    Night Charge -2.129452  0.975454
# 58       Intl Mins  1.267818  0.632564
# 59      Intl Calls -0.205038  0.374331
# 60     Intl Charge  1.612493  0.461256
# 61  CustServ Calls  1.750607  0.363537
# 62          Churn? -1.518927  0.261823
